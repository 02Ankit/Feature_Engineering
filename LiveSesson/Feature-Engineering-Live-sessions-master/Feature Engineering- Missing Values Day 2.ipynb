# %% [markdown]
# ### 2. Random Sample Imputation
#
# Aim: Random sample imputation consists of taking random observation from the dataset and we use this observation to replace the nan values
#
# When should it be used?
# It assumes that the data are missing completely at random(MCAR)

# %%
import pandas as pd
df=pd.read_csv('titanic.csv', usecols=['Age','Fare','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
## Sample() is given random values initialize 
df['Age'].dropna().sample(df['Age'].isnull().sum(), random_state=0)

## here the value is replaced
# 423 is replace by 28.00
# 177 is Repace by 50.00
## So On.....
# Out:
# 423    28.00
# 177    50.00
# 305     0.92
# 292    36.00
# 889    26.00
#        ...
# 539    22.00
# 267    25.00
# 352    15.00
# 99     34.00
# 689    15.00
# Name: Age, Length: 177, dtype: float64

# %%
df['Age'].dropna().sample(df['Age'].isnull().sum(),random_state=0)
# Out:
# 423    28.00
# 177    50.00
# 305     0.92
# 292    36.00
# 889    26.00
# 595    36.00
# 637    31.00
# 54     65.00
# 456    65.00
# 110    47.00
# 287    22.00
# 315    26.00
# 691     4.00
# 811    39.00
# 861    21.00
# 15     55.00
# 239    33.00
# 644     0.75
# 394    24.00
# 795    39.00
# 131    20.00
# 346    40.00
# 9      14.00
# 477    29.00
# 606    30.00
# 469     0.75
# 325    36.00
# 72     21.00
# 724    27.00
# 40     40.00
#        ...
# 396    31.00
# 452    30.00
# 395    22.00
# 882    22.00
# 821    27.00
# 314    43.00
# 622    20.00
# 204    18.00
# 60     22.00
# 731    11.00
# 81     29.00
# 676    24.50
# 433    17.00
# 378    20.00
# 174    56.00
# 624    21.00
# 642     2.00
# 157    30.00
# 427    19.00
# 698    49.00
# 179    36.00
# 24      8.00
# 630    80.00
# 458    50.00
# 49     18.00
# 539    22.00
# 267    25.00
# 352    15.00
# 99     34.00
# 689    15.00
# Name: Age, Length: 177, dtype: float64

# %%
df[df['Age'].isnull()].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
def impute_nan(df,variable,median):
    df[variable+"_median"]=df[variable].fillna(median)
    df[variable+"_random"]=df[variable]
    ##It will have the random sample to fill the na
    random_sample=df[variable].dropna().sample(df[variable].isnull().sum(),random_state=0)
    ##pandas need to have same index in order to merge the dataset
    random_sample.index=df[df[variable].isnull()].index
    ## variable Replace kiya hai bus jyada kuch nahi 
    df.loc[df[variable].isnull(),variable+'_random']=random_sample

# %%
median=df.Age.median()

# %%
median
# Out:
# 28.0

# %%
impute_nan(df,"Age",median)

# %%
df.head()
# Out:
#    Survived   Age     Fare  Age_median  Age_random
# 0         0  22.0   7.2500        22.0        22.0
# 1         1  38.0  71.2833        38.0        38.0
# 2         1  26.0   7.9250        26.0        26.0
# 3         1  35.0  53.1000        35.0        35.0
# 4         0  35.0   8.0500        35.0        35.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df['Age'].plot(kind='kde', ax=ax)
df.Age_median.plot(kind='kde', ax=ax, color='red')
df.Age_random.plot(kind='kde', ax=ax, color='green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %% [markdown]
# ##### Advantages
# 1. Easy To implement
# 2. There is less distortion in variance
#
# ##### Disadvantage
# 1. Every situation randomness wont work

# %% [markdown]
# ### 3. Capturing NAN values with a new feature
#
# It works well if the data are not missing completely at random (MCNAR)

# %%
df=pd.read_csv('titanic.csv', usecols=['Age','Fare','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
import numpy as np
df['Age_NAN']=np.where(df['Age'].isnull(),1,0)

# %%
df.head(50)
# Out:
#     Survived   Age      Fare  Age_NAN
# 0          0  22.0    7.2500        0
# 1          1  38.0   71.2833        0
# 2          1  26.0    7.9250        0
# 3          1  35.0   53.1000        0
# 4          0  35.0    8.0500        0
# 5          0   NaN    8.4583        1
# 6          0  54.0   51.8625        0
# 7          0   2.0   21.0750        0
# 8          1  27.0   11.1333        0
# 9          1  14.0   30.0708        0
# 10         1   4.0   16.7000        0
# 11         1  58.0   26.5500        0
# 12         0  20.0    8.0500        0
# 13         0  39.0   31.2750        0
# 14         0  14.0    7.8542        0
# 15         1  55.0   16.0000        0
# 16         0   2.0   29.1250        0
# 17         1   NaN   13.0000        1
# 18         0  31.0   18.0000        0
# 19         1   NaN    7.2250        1
# 20         0  35.0   26.0000        0
# 21         1  34.0   13.0000        0
# 22         1  15.0    8.0292        0
# 23         1  28.0   35.5000        0
# ...

# %%
df.Age.median()
# Out:
# 28.0

# %%
# Inplcae = True Means Completely Update the Data
df['Age'].fillna(df.Age.median(),inplace=True)

# %%
df.head(50)
## We can use also random Sample
# Out:
#     Survived   Age      Fare  Age_NAN
# 0          0  22.0    7.2500        0
# 1          1  38.0   71.2833        0
# 2          1  26.0    7.9250        0
# 3          1  35.0   53.1000        0
# 4          0  35.0    8.0500        0
# 5          0  28.0    8.4583        1
# 6          0  54.0   51.8625        0
# 7          0   2.0   21.0750        0
# 8          1  27.0   11.1333        0
# 9          1  14.0   30.0708        0
# 10         1   4.0   16.7000        0
# 11         1  58.0   26.5500        0
# 12         0  20.0    8.0500        0
# 13         0  39.0   31.2750        0
# 14         0  14.0    7.8542        0
# 15         1  55.0   16.0000        0
# 16         0   2.0   29.1250        0
# 17         1  28.0   13.0000        1
# 18         0  31.0   18.0000        0
# 19         1  28.0    7.2250        1
# 20         0  35.0   26.0000        0
# 21         1  34.0   13.0000        0
# 22         1  15.0    8.0292        0
# 23         1  28.0   35.5000        0
# ...

# %% [markdown]
# #### Advantages
# 1. Easy to implement
# 2. Captures the importance of missing values
#
# ##### Disadvantages
# 1. Creating Additional Features(Curse of Dimensionality)

# %% [markdown]
# ### 4. End of Distribution imputation

# %%
df=pd.read_csv('titanic.csv', usecols=['Age','Fare','Survived'])
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.Age.hist(bins=50)
# Out:
# <Axes: >

# %%
# Here Give central of the distribution 
df.Age.mean()
# Out:
# 29.69911764705882

# %%
## First Standard deviation
df.Age.mean()+df.Age.std()
# Out:
# 44.22561497939286

# %%
## Second Standard deviation
df.Age.mean()+2*df.Age.std()
# Out:
# 58.752112311726904

# %%
## We can take right distribution of the Data 
## Third Standard deviation
extreme=df.Age.mean()+3*df.Age.std()

# %%
## Distribution of the Data Use the Box Plot 
import seaborn as sns
sns.boxplot(data=df, orient='h')
# Out:
# <Axes: >

# %%
def impute_nan(df,variable,median,extreme):
    df[variable+"_end_distribution"]=df[variable].fillna(extreme)
    df[variable].fillna(median,inplace=True)

# %%
impute_nan(df,'Age',df.Age.median(),extreme)

# %%
df.head(20)
# Out:
#     Survived   Age     Fare  Age_end_distribution
# 0          0  22.0   7.2500              22.00000
# 1          1  38.0  71.2833              38.00000
# 2          1  26.0   7.9250              26.00000
# 3          1  35.0  53.1000              35.00000
# 4          0  35.0   8.0500              35.00000
# 5          0  28.0   8.4583              73.27861
# 6          0  54.0  51.8625              54.00000
# 7          0   2.0  21.0750               2.00000
# 8          1  27.0  11.1333              27.00000
# 9          1  14.0  30.0708              14.00000
# 10         1   4.0  16.7000               4.00000
# 11         1  58.0  26.5500              58.00000
# 12         0  20.0   8.0500              20.00000
# 13         0  39.0  31.2750              39.00000
# 14         0  14.0   7.8542              14.00000
# 15         1  55.0  16.0000              55.00000
# 16         0   2.0  29.1250               2.00000
# 17         1  28.0  13.0000              73.27861
# ...

# %%
df['Age'].hist(bins=50)
# Out:
# <Axes: >

# %%
df['Age_end_distribution'].hist(bins=50)
# Out:
# <Axes: >

# %%
sns.boxplot('Age_end_distribution',data=df)
## There Is No Outliers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 sns.boxplot('Age_end_distribution',data=df)
#
# TypeError: boxplot() got multiple values for argument 'data'
